# %% [markdown]
# <a href="https://colab.research.google.com/github/soyoung33500/Video/blob/main/%EA%B7%B8%EB%9E%98%ED%94%84_%EB%B9%84%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # csv 파일 읽어오기

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/result
# Out:
# /content/drive/MyDrive/Colab Notebooks/result

# %%
# csv 파일 읽기
Mdf01 = pd.read_csv("Mresult01.csv", index_col = 0)
Mdf02 = pd.read_csv("Mresult02.csv", index_col = 0)
Mdf03 = pd.read_csv("Mresult03.csv", index_col = 0)
Mdf04 = pd.read_csv("Mresult04.csv", index_col = 0)
Xdf01 = pd.read_csv("Xresult01.csv", index_col = 0)
Xdf02 = pd.read_csv("Xresult02.csv", index_col = 0)
Xdf03 = pd.read_csv("Xresult03.csv", index_col = 0)
Xdf04 = pd.read_csv("Xresult04.csv", index_col = 0)
Idf01 = pd.read_csv("Iresult01.csv", index_col = 0)
Idf02 = pd.read_csv("Iresult02.csv", index_col = 0)
Idf03 = pd.read_csv("Iresult03.csv", index_col = 0)
Idf04 = pd.read_csv("Iresult04.csv", index_col = 0)
Rdf01 = pd.read_csv("Rresult01.csv", index_col = 0)
Rdf02 = pd.read_csv("Rresult02.csv", index_col = 0)
Rdf03 = pd.read_csv("Rresult03.csv", index_col = 0)
Rdf04 = pd.read_csv("Rresult04.csv", index_col = 0)
i3ddf01 = pd.read_csv("i3dresult01.csv", index_col = 0)
i3ddf02 = pd.read_csv("i3dresult02.csv", index_col = 0)

# %% [markdown]
# # 모델별 성능 Accuracy 비교 (기본증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf01['acc'], label='MobileNet Accuracy', color = 'orange')
plt.plot(Xdf01['acc'], label='Xception Accuracy', color = 'green')
plt.plot(Idf01['acc'], label='Inception Accuracy', color = 'blue')
plt.plot(i3ddf01['acc'], label='i3d Accuracy', color = 'red')
plt.plot(range(0, 20), Rdf01['acc'][-20:], label='ResNet152 Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Accuracy 비교 (기본증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_acc'], label='MobileNet Validation Accuracy', color = 'orange')
plt.plot(Xdf01['val_acc'], label='Xception Validation Accuracy', color = 'green')
plt.plot(Idf01['val_acc'], label='Inception Validation Accuracy', color = 'blue')
plt.plot(i3ddf01['val_acc'], label='i3d Validation Accuracy', color = 'red')
plt.plot(range(0, 20), Rdf01['val_acc'][-20:], label='ResNet152 Validation Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Loss 비교 (기본증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf01['loss'], label='MobileNet Loss', color = 'orange')
plt.plot(Xdf01['loss'], label='Xception Loss', color = 'green')
plt.plot(Idf01['loss'], label='Inception Loss', color = 'blue')
plt.plot(i3ddf01['loss'], label='i3d Loss', color = 'red')
plt.plot(range(0, 20), Rdf01['loss'][-20:], label='ResNet152 Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Loss 비교 (기본증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_loss'], label='MobileNet Validation Loss', color = 'orange')
plt.plot(Xdf01['val_loss'], label='Xception Validation Loss', color = 'green')
plt.plot(Idf01['val_loss'], label='Inception Validation Loss', color = 'blue')
plt.plot(i3ddf01['val_loss'], label='i3d Validation Loss', color = 'red')
plt.plot(range(0, 20), Rdf01['val_loss'][-20:], label='ResNet152 Validation Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # @@@@@@@@@@

# %% [markdown]
# ---
# # 각 모델마다 증강 차이 Accuracy 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['acc'], label='Default Accuracy', color = 'orange')
plt.plot(Mdf02['acc'], label='Update Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_acc'], label='Default Validation Accuracy', color = 'orange')
plt.plot(Mdf02['val_acc'], label='Update Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['acc'], label='Default Accuracy', color = 'orange')
plt.plot(Xdf02['acc'], label='Update Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_acc'], label='Default Validation Accuracy', color = 'orange')
plt.plot(Xdf02['val_acc'], label='Update Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['acc'], label='Default Accuracy', color = 'orange')
plt.plot(Idf02['acc'], label='Update Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_acc'], label='Default Validation Accuracy', color = 'orange')
plt.plot(Idf02['val_acc'], label='Update Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['acc'][-20:], label='Default Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf02['acc'][-20:], label='Update Accuracy', color = 'green')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['val_acc'][-20:], label='Default Validation Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf02['val_acc'][-20:], label='Update Validation Accuracy', color = 'green')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### i3d

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['acc'], label='Default Accuracy', color = 'orange')
plt.plot(i3ddf02['acc'], label='Update Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['val_acc'], label='Default Validation Accuracy', color = 'orange')
plt.plot(i3ddf02['val_acc'], label='Update Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 각 모델마다 증강 차이 Loss 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['loss'], label='Default Loss', color = 'orange')
plt.plot(Mdf02['loss'], label='Update Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_loss'], label='Default Validation Loss', color = 'orange')
plt.plot(Mdf02['val_loss'], label='Update Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['loss'], label='Default Loss', color = 'orange')
plt.plot(Xdf02['loss'], label='Update Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_loss'], label='Default Validation Loss', color = 'orange')
plt.plot(Xdf02['val_loss'], label='Update Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['loss'], label='Default Loss', color = 'orange')
plt.plot(Idf02['loss'], label='Update Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_loss'], label='Default Validation Loss', color = 'orange')
plt.plot(Idf02['val_loss'], label='Update Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['loss'], label='Default Loss', color = 'orange')
plt.plot(i3ddf02['loss'], label='Update Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['val_loss'], label='Default Validation Loss', color = 'orange')
plt.plot(i3ddf02['val_loss'], label='Update Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### i3d (수정했습니다)

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['loss'], label='Default Loss', color = 'orange')
plt.plot(i3ddf02['loss'], label='Update Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['val_loss'], label='Default Validation Loss', color = 'orange')
plt.plot(i3ddf02['val_loss'], label='Update Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Accuracy 비교 (바꾼증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf02['acc'], label='MobileNet Accuracy', color = 'orange')
plt.plot(Xdf02['acc'], label='Xception Accuracy', color = 'green')
plt.plot(Idf02['acc'], label='Inception Accuracy', color = 'blue')
plt.plot(i3ddf02['acc'], label='i3d Accuracy', color = 'red')
plt.plot(range(0, 20), Rdf02['acc'][-20:], label='ResNet152 Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Accuracy 비교 (바꾼증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf02['val_acc'], label='MobileNet Validation Accuracy', color = 'orange')
plt.plot(Xdf02['val_acc'], label='Xception Validation Accuracy', color = 'green')
plt.plot(Idf02['val_acc'], label='Inception Validation Accuracy', color = 'blue')
plt.plot(i3ddf02['val_acc'], label='i3d Validation Accuracy', color = 'red')
plt.plot(range(0, 20), Rdf02['val_acc'][-20:], label='ResNet152 Validation Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Loss 비교 (바꾼증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf02['loss'], label='MobileNet Loss', color = 'orange')
plt.plot(Xdf02['loss'], label='Xception Loss', color = 'green')
plt.plot(Idf02['loss'], label='Inception Loss', color = 'blue')
plt.plot(i3ddf02['loss'], label='i3d Loss', color = 'red')
plt.plot(range(0, 20), Rdf02['loss'][-20:], label='ResNet152 Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Loss 비교 (바꾼증강 + LSTM)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf02['val_loss'], label='MobileNet Validation Loss', color = 'orange')
plt.plot(Xdf02['val_loss'], label='Xception Validation Loss', color = 'green')
plt.plot(Idf02['val_loss'], label='Inception Validation Loss', color = 'blue')
plt.plot(i3ddf02['val_loss'], label='i3d Validation Loss', color = 'red')
plt.plot(range(0, 20), Rdf02['val_loss'][-20:], label='ResNet152 Validation Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # @@@@@@@@@@

# %% [markdown]
# ---
# # 각 모델마다 RNN 차이 Accuracy 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['acc'], label='LSTM Accuracy', color = 'orange')
plt.plot(Mdf03['acc'], label='GRU Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_acc'], label='LSTM Validation Accuracy', color = 'orange')
plt.plot(Mdf03['val_acc'], label='GRU Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['acc'], label='LSTM Accuracy', color = 'orange')
plt.plot(Xdf03['acc'], label='GRU Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_acc'], label='LSTM Validation Accuracy', color = 'orange')
plt.plot(Xdf03['val_acc'], label='GRU Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['acc'], label='LSTM Accuracy', color = 'orange')
plt.plot(Idf03['acc'], label='GRU Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_acc'], label='LSTM Validation Accuracy', color = 'orange')
plt.plot(Idf03['val_acc'], label='GRU Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['acc'][-20:], label='LSTM Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf03['acc'][-20:], label='GRU Accuracy', color = 'green')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['val_acc'][-20:], label='LSTM Validation Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf03['val_acc'][-20:], label='GRU Validation Accuracy', color = 'green')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 각 모델마다 RNN 차이 Loss 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['loss'], label='LSTM Loss', color = 'orange')
plt.plot(Mdf03['loss'], label='GRU Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_loss'], label='LSTM Validation Loss', color = 'orange')
plt.plot(Mdf03['val_loss'], label='GRU Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['loss'], label='LSTM Loss', color = 'orange')
plt.plot(Xdf03['loss'], label='GRU Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_loss'], label='LSTM Validation Loss', color = 'orange')
plt.plot(Xdf03['val_loss'], label='GRU Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['loss'], label='LSTM Loss', color = 'orange')
plt.plot(Idf03['loss'], label='GRU Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_loss'], label='LSTM Validation Loss', color = 'orange')
plt.plot(Idf03['val_loss'], label='GRU Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['loss'][-20:], label='LSTM Loss', color = 'orange')
plt.plot(range(0, 20), Rdf03['loss'][-20:], label='GRU Loss', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['val_loss'][-20:], label='LSTM Validation Loss', color = 'orange')
plt.plot(range(0, 20), Rdf03['val_loss'][-20:], label='GRU Validation Loss', color = 'green')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Accuracy 비교 (기본증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf03['acc'], label='MobileNet Accuracy', color = 'orange')
plt.plot(Xdf03['acc'], label='Xception Accuracy', color = 'green')
plt.plot(Idf03['acc'], label='Inception Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf03['acc'][-20:], label='ResNet152 Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Accuracy 비교 (기본증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf03['val_acc'], label='MobileNet Validation Accuracy', color = 'orange')
plt.plot(Xdf03['val_acc'], label='Xception Validation Accuracy', color = 'green')
plt.plot(Idf03['val_acc'], label='Inception Validation Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf03['val_acc'][-20:], label='ResNet152 Validation Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Loss 비교 (기본증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf03['loss'], label='MobileNet Loss', color = 'orange')
plt.plot(Xdf03['loss'], label='Xception Loss', color = 'green')
plt.plot(Idf03['loss'], label='Inception Loss', color = 'blue')
plt.plot(range(0, 20), Rdf03['loss'][-20:], label='ResNet152 Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Loss 비교 (기본증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf03['val_loss'], label='MobileNet Validation Loss', color = 'orange')
plt.plot(Xdf03['val_loss'], label='Xception Validation Loss', color = 'green')
plt.plot(Idf03['val_loss'], label='Inception Validation Loss', color = 'blue')
plt.plot(range(0, 20), Rdf03['val_loss'][-20:], label='ResNet152 Validation Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # @@@@@@@@@@

# %% [markdown]
# # 모델별 성능 Accuracy 비교 (바꾼증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf04['acc'], label='MobileNet Accuracy', color = 'orange')
plt.plot(Xdf04['acc'], label='Xception Accuracy', color = 'green')
plt.plot(Idf04['acc'], label='Inception Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf04['acc'][-20:], label='ResNet152 Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Accuracy 비교 (바꾼증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf04['val_acc'], label='MobileNet Validation Accuracy', color = 'orange')
plt.plot(Xdf04['val_acc'], label='Xception Validation Accuracy', color = 'green')
plt.plot(Idf04['val_acc'], label='Inception Validation Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf04['val_acc'][-20:], label='ResNet152 Validation Accuracy', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Loss 비교 (바꾼증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf04['loss'], label='MobileNet Loss', color = 'orange')
plt.plot(Xdf04['loss'], label='Xception Loss', color = 'green')
plt.plot(Idf04['loss'], label='Inception Loss', color = 'blue')
plt.plot(range(0, 20), Rdf04['loss'][-20:], label='ResNet152 Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0,max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 모델별 성능 Validation Loss 비교 (바꾼증강 + GRU)

# %%
plt.figure(figsize=(13, 6))
plt.grid(alpha=0.5)
plt.plot(Mdf04['val_loss'], label='MobileNet Validation Loss', color = 'orange')
plt.plot(Xdf04['val_loss'], label='Xception Validation Loss', color = 'green')
plt.plot(Idf04['val_loss'], label='Inception Validation Loss', color = 'blue')
plt.plot(range(0, 20), Rdf04['val_loss'][-20:], label='ResNet152 Validation Loss', color = 'black')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 15)
#plt.tight_layout()
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, max(plt.ylim())])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # @@@@@@@@@@

# %% [markdown]
# # 모델마다 모든 결과 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['acc'], label='Default LSTM Accuracy', color = 'orange')
plt.plot(Mdf02['acc'], label='Update LSTM Accuracy', color = 'green')
plt.plot(Mdf03['acc'], label='Default GRU Accuracy', color = 'blue')
plt.plot(Mdf04['acc'], label='Update GRU Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 13)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_acc'], label='Default LSTM Validation Accuracy', color = 'orange')
plt.plot(Mdf02['val_acc'], label='Update LSTM Validation Accuracy', color = 'green')
plt.plot(Mdf03['val_acc'], label='Default GRU Validation Accuracy', color = 'blue')
plt.plot(Mdf04['val_acc'], label='Update GRU Validation Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 13)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception (수정했습니다)

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['acc'], label='Default LSTM Accuracy', color = 'orange')
plt.plot(Xdf02['acc'], label='Update LSTM Accuracy', color = 'green')
plt.plot(Xdf03['acc'], label='Default GRU Accuracy', color = 'blue')
plt.plot(Xdf04['acc'], label='Update GRU Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 12)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_acc'], label='Default LSTM Validation Accuracy', color = 'orange')
plt.plot(Xdf02['val_acc'], label='Update LSTM Validation Accuracy', color = 'green')
plt.plot(Xdf03['val_acc'], label='Default GRU Validation Accuracy', color = 'blue')
plt.plot(Xdf04['val_acc'], label='Update GRU Validation Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 12)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['acc'], label='Default LSTM Accuracy', color = 'orange')
plt.plot(Idf02['acc'], label='Update LSTM Accuracy', color = 'green')
plt.plot(Idf03['acc'], label='Default GRU Accuracy', color = 'blue')
plt.plot(Idf04['acc'], label='Update GRU Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_acc'], label='Default LSTM Validation Accuracy', color = 'orange')
plt.plot(Idf02['val_acc'], label='Update LSTM Validation Accuracy', color = 'green')
plt.plot(Idf03['val_acc'], label='Default GRU Validation Accuracy', color = 'blue')
plt.plot(Idf04['val_acc'], label='Update GRU Validation Accuracy', color = 'black')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['acc'][-20:], label='Default LSTM Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf02['acc'][-20:], label='Update LSTM Accuracy', color = 'green')
plt.plot(range(0, 20), Rdf03['acc'][-20:], label='Default GRU Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf04['acc'][-20:], label='Update GRU Accuracy', color = 'black')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['val_acc'][-20:], label='Default LSTM Validation Accuracy', color = 'orange')
plt.plot(range(0, 20), Rdf02['val_acc'][-20:], label='Update LSTM Validation Accuracy', color = 'green')
plt.plot(range(0, 20), Rdf03['val_acc'][-20:], label='Default GRU Validation Accuracy', color = 'blue')
plt.plot(range(0, 20), Rdf04['val_acc'][-20:], label='Update GRU Validation Accuracy', color = 'black')
plt.legend(loc='upper left', fontsize = 15)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### i3d

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['acc'], label='Default LSTM Accuracy', color = 'orange')
plt.plot(i3ddf02['acc'], label='Update LSTM Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 13)
plt.ylabel('Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Accuracy Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['val_acc'], label='Default LSTM Validation Accuracy', color = 'orange')
plt.plot(i3ddf02['val_acc'], label='Update LSTM Validation Accuracy', color = 'green')
plt.legend(loc='lower right', fontsize = 13)
plt.ylabel('Validation Accuracy', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0.2,1])
plt.xticks(range(0, 20, 2))
plt.title('Validation Accuracy Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# # 각 모델마다 증강 차이 Loss 비교

# %% [markdown]
# ### MobileNet

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Mdf01['loss'], label='Default LSTM Loss', color = 'orange')
plt.plot(Mdf02['loss'], label='Update LSTM Loss', color = 'green')
plt.plot(Mdf03['loss'], label='Default GRU Loss', color = 'blue')
plt.plot(Mdf04['loss'], label='Update GRU Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Mdf01['val_loss'], label='Default LSTM Validation Loss', color = 'orange')
plt.plot(Mdf02['val_loss'], label='Update LSTM Validation Loss', color = 'green')
plt.plot(Mdf03['val_loss'], label='Default GRU Validation Loss', color = 'blue')
plt.plot(Mdf04['val_loss'], label='Update GRU Validation Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Xception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Xdf01['loss'], label='Default LSTM Loss', color = 'orange')
plt.plot(Xdf02['loss'], label='Update LSTM Loss', color = 'green')
plt.plot(Xdf03['loss'], label='Default GRU Loss', color = 'blue')
plt.plot(Xdf04['loss'], label='Update GRU Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Xdf01['val_loss'], label='Default LSTM Validation Loss', color = 'orange')
plt.plot(Xdf02['val_loss'], label='Update LSTM Validation Loss', color = 'green')
plt.plot(Xdf03['val_loss'], label='Default GRU Validation Loss', color = 'blue')
plt.plot(Xdf04['val_loss'], label='Update GRU Validation Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### Inception

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(Idf01['loss'], label='Default LSTM Loss', color = 'orange')
plt.plot(Idf02['loss'], label='Update LSTM Loss', color = 'green')
plt.plot(Idf03['loss'], label='Default GRU Loss', color = 'blue')
plt.plot(Idf04['loss'], label='Update GRU Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(Idf01['val_loss'], label='Default LSTM Validation Loss', color = 'orange')
plt.plot(Idf02['val_loss'], label='Update LSTM Validation Loss', color = 'green')
plt.plot(Idf03['val_loss'], label='Default GRU Validation Loss', color = 'blue')
plt.plot(Idf04['val_loss'], label='Update GRU Validation Loss', color = 'black')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### ResNet152

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['loss'][-20:], label='Default LSTM Loss', color = 'orange')
plt.plot(range(0, 20), Rdf02['loss'][-20:], label='Update LSTM Loss', color = 'green')
plt.plot(range(0, 20), Rdf03['loss'][-20:], label='Default GRU Loss', color = 'blue')
plt.plot(range(0, 20), Rdf04['loss'][-20:], label='Update GRU Loss', color = 'black')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(range(0, 20), Rdf01['val_loss'][-20:], label='Default LSTM Validation Loss', color = 'orange')
plt.plot(range(0, 20), Rdf02['val_loss'][-20:], label='Update LSTM Validation Loss', color = 'green')
plt.plot(range(0, 20), Rdf03['val_loss'][-20:], label='Default GRU Validation Loss', color = 'blue')
plt.plot(range(0, 20), Rdf04['val_loss'][-20:], label='Update GRU Validation Loss', color = 'black')
plt.legend(loc='lower right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()

# %% [markdown]
# ### i3d (수정했습니다)

# %%
plt.figure(figsize=(18, 5))
plt.subplot(1, 2, 1)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['loss'], label='Default LSTM Loss', color = 'orange')
plt.plot(i3ddf02['loss'], label='Update LSTM Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Loss Comparison', fontsize = 20)
plt.subplot(1, 2, 2)
plt.grid(alpha=0.5)
plt.plot(i3ddf01['val_loss'], label='Default LSTM Validation Loss', color = 'orange')
plt.plot(i3ddf02['val_loss'], label='Update LSTM Validation Loss', color = 'green')
plt.legend(loc='upper right', fontsize = 15)
plt.ylabel('Validation Loss', fontsize = 15)
plt.xlabel('epoch', fontsize = 15)
plt.ylim([0, 1.3])
plt.xticks(range(0, 20, 2))
plt.title('Validation Loss Comparison', fontsize = 20)
plt.show()
